# %% [markdown]
# Taller Final Randon Forest Clasification - Validation - Test

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support, roc_auc_score, ConfusionMatrixDisplay

# %%
# Load the data
data = pd.read_csv('creditcard_2023.csv')

# Remove the 'id' column
data = data.drop(columns=['id'])

# Remove duplicates
data = data.drop_duplicates()

# Standardize the 'Amount' column
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# Split the dataset into features and target variable
x_data = data.drop(columns=['Class'])  # Features (all columns except 'Class')
y_data = data['Class']  # Target variable

# Split the data into a combined training + validation set and a test set.
X_train_val, X_val, y_train_val, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42, stratify=y_data)

# Split the training + validation set further into separate training and validation sets.
X_train, X_test, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42, stratify=y_train_val)  # 0.25 x 0.8 = 0.2

# Check the shape of the input and target data
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (341177, 29) (113726, 29) (341177,) (113726,)

# %%
# Initialize a Random Forest classifier with default parameters.
rf_classifier = RandomForestClassifier(random_state=42)

# Train the classifier with the training data.
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Se predicen las classes usando el DF de test
y_val_pred = rf_classifier.predict(X_val)

#Se calculan las metricas de evalucacion 
conf_matrix = confusion_matrix(y_val, y_val_pred)
class_report = classification_report(y_val, y_val_pred)
accuracy = accuracy_score(y_val, y_val_pred)
precision, recall, f1_score, _ = precision_recall_fscore_support(y_val, y_val_pred, average='binary')
roc_auc = roc_auc_score(y_val, y_val_pred)

# Print the performance metrics.
print("Confusion Matrix:")
print(conf_matrix)
disp = ConfusionMatrixDisplay(conf_matrix)
disp.plot()
plt.show()

print("\nClassification Report:")
print(class_report)

print("\nScores:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"ROC AUC: {roc_auc}")
# Out:
# Confusion Matrix:
# [[56850    13]
#  [    0 56863]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       1.00      1.00      1.00     56863
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
# Scores:
# Accuracy: 0.9998856901675958
# Precision: 0.9997714325901962
# Recall: 1.0
# F1 Score: 0.9998857032328401
# ROC AUC: 0.9998856901675959

# %%
#Se predicen las classes usando el DF de test
y_test_pred = rf_classifier.predict(X_test)

#Se calculan las metricas de evalucacion 
conf_matrix = confusion_matrix(y_test, y_test_pred)
class_report = classification_report(y_test, y_test_pred)
accuracy = accuracy_score(y_test, y_test_pred)
precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_test_pred, average='binary')
roc_auc = roc_auc_score(y_test, y_test_pred)

# Print the performance metrics.
print("Confusion Matrix:")
print(conf_matrix)
disp = ConfusionMatrixDisplay(conf_matrix)
disp.plot()
plt.show()

print("\nClassification Report:")
print(class_report)

print("\nScores:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
print(f"ROC AUC: {roc_auc}")
# Out:
# Confusion Matrix:
# [[56839    24]
#  [    1 56862]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       1.00      1.00      1.00     56863
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
#
# Scores:
# Accuracy: 0.9997801733992226
# Precision: 0.9995781035755722
# Recall: 0.9999824138719379
# F1 Score: 0.999780217848069
# ROC AUC: 0.9997801733992226
